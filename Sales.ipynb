# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# loading data
df = pd.read_csv("1500000 Sales Records(1).csv")
df.head()
# Out:
#                          Region           Country  Item Type Sales Channel  \
# 0            Sub-Saharan Africa      South Africa     Fruits       Offline
# 1  Middle East and North Africa           Morocco    Clothes        Online
# 2         Australia and Oceania  Papua New Guinea       Meat       Offline
# 3            Sub-Saharan Africa          Djibouti    Clothes       Offline
# 4                        Europe          Slovakia  Beverages       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M   7/27/2012  443368995   7/28/2012        1593        9.33
# 1              M   9/14/2013  667593514  10/19/2013        4611      109.28
# 2              M   5/15/2015  940995585  06/04/2015         360      421.89
# 3              H   5/17/2017  880811536  07/02/2017         562      109.28
# 4              L  10/26/2016  174590194  12/04/2016        3973       47.45
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0       6.92       14862.69    11023.56       3839.13
# 1      35.84      503890.08   165258.24     338631.84
# 2     364.69      151880.40   131288.40      20592.00
# 3      35.84       61415.36    20142.08      41273.28
# 4      31.79      188518.85   126301.67      62217.18

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396536 entries, 0 to 396535
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Region          396536 non-null  object
#  1   Country         396536 non-null  object
#  2   Item Type       396536 non-null  object
#  3   Sales Channel   396536 non-null  object
#  4   Order Priority  396536 non-null  object
#  5   Order Date      396536 non-null  object
#  6   Order ID        396536 non-null  int64
#  7   Ship Date       396536 non-null  object
#  8   Units Sold      396536 non-null  int64
#  9   Unit Price      396536 non-null  float64
#  10  Unit Cost       396536 non-null  float64
#  11  Total Revenue   396536 non-null  float64
#  12  Total Cost      396536 non-null  float64
#  13  Total Profit    396536 non-null  float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 42.4+ MB

# %%
# Compute correlation matrix

corr_matrix = df[['Units Sold', 'Unit Price', 'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit']].corr()

# Plot heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

# Title
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 3))  # Adjust size as needed
ax.axis('off')  # Hide axes

# Add table
table = ax.table(cellText=corr_matrix.round(2).values, 
                 rowLabels=corr_matrix.index, 
                 colLabels=corr_matrix.columns, 
                 cellLoc='center', 
                 loc='center')

# Adjust table properties
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.2)  # Adjust table size
ax.set_title("Correlation Matrix (Table)")

# Show the table
plt.show()
