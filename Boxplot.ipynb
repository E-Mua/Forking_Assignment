# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
file_path = "1500000 Sales Records(1).csv" # Update path accordingly
df = pd.read_csv(file_path)
df.columns
#df.head
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\USER\\Documents\\GitHub\\Forking_Assignment'

# %%
# Create the box plot
plt.figure(figsize=(8, 5))
sns.boxplot(x='Item Type', y='Total Revenue', data=df, palette='Set2')

# Customize plot
plt.title('Box Plot of Total Revenue by Item Type')
plt.xlabel('Item Type')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)
# Show plot
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_31352\1585187885.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Item Type', y='Total Revenue', data=df, palette='Set2')
